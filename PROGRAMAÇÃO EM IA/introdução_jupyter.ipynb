# %% [markdown]
# # título

# %% [markdown]
# **listas**
# - item 1
# - item 2
# - item 3

# %%
print("ola mundo")
# Out:
# ola mundo

# %%
a = 2

# %%
print(a)
print(b)
# Out:
# 2

# %%
b = 5

# %% [markdown]
# # pandas

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.8 MB 17.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 21.0 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.8 MB 16.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 12.6 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 9.1 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 15.0 MB/s eta 0:00:01
#    -- ------------------------------------- 0.8/12.4 MB 2.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/12.4 MB 2.1 MB/s eta 0:00:06
# ...

# %%
import pandas as pd

# %%
carros = {
    "modelo" : ["mustang","dodge challenger","gtr","mcllaren",],
    "ano" : [2008,2016,2020,2025],
    "valor" : [28600,300000,800000,1500000]
}

# %%
df = pd.DataFrame(carros)
df
# Out:
#              modelo   ano    valor
# 0           mustang  2008    28600
# 1  dodge challenger  2016   300000
# 2               gtr  2020   800000
# 3          mcllaren  2025  1500000
